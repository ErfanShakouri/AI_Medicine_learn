# %%
# Install the pydicom library if not already installed
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.4 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.1

# %%
# Import required libraries
import pydicom
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Read a single DICOM file from the specified path
pydicom_file = pydicom.dcmread('/dicom_dir/ID_0015_AGE_0061_CONTRAST_1_CT.dcm')

# %%
pydicom_file
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 194
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.612696157451530634003461974920
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002,0013) Implementation Version Name         SH: 'dcm4che-1.4.31'
# -------------------------------------------------
# (0008,0000) Group Length                        UL: 458
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008,0016) SOP Class UID                       UI: CT Image Storage
# (0008,0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.612696157451530634003461974920
# (0008,0020) Study Date                          DA: '19840713'
# (0008,0021) Series Date                         DA: '19840713'
# (0008,0022) Acquisition Date                    DA: '19840713'
# (0008,0023) Content Date                        DA: '19840713'
# (0008,0030) Study Time                          TM: '082819.343000'
# (0008,0031) Series Time                         TM: '084027.265000'
# (0008,0032) Acquisition Time                    TM: '083734.355000'
# (0008,0033) Content Time                        TM: '083734.355000'
# (0008,0040) Data Set Type                       US: 0
# (0008,0041) Data Set Subtype                    LO: 'IMA SPI'
# (0008,0050) Accession Number                    SH: '3109136840619464'
# (0008,0060) Modality                            CS: 'CT'
# (0008,0070) Manufacturer                        LO: 'SIEMENS'
# (0008,0090) Referring Physician's Name          PN: ''
# (0008,1010) Station Name                        SH: ''
# (0008,103E) Series Description                  LO: 'PE-Fast #2'
# (0008,1080) Admitting Diagnoses Description     LO: ''
# (0008,1090) Manufacturer's Model Name           LO: 'Volume Zoom'
# (0009,0000) Private Creator                     UN: b'N\x00\x00\x00'
# (0009,0010) Private tag data                    LO: 'SIEMENS CT VA1 DUMMY'
# (0009,0011) Private tag data                    LO: 'SPI RELEASE 1'
# (0009,0012) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
# (0010,0000) Group Length                        UL: 88
# (0010,0010) Patient's Name                      PN: 'TCGA-17-Z043'
# (0010,0020) Patient ID                          LO: 'TCGA-17-Z043'
# (0010,0030) Patient's Birth Date                DA: ''
# (0010,0040) Patient's Sex                       CS: 'F'
# (0010,1010) Patient's Age                       AS: '061Y'
# (0010,21C0) Pregnancy Status                    US: 4
# (0010,4000) Patient Comments                    LT: ''
# (0011,0000) Private Creator                     UN: b'*\x00\x00\x00'
# (0011,0010) Private tag data                    LO: 'SPI RELEASE 1'
# (0011,0011) Private tag data                    LO: 'SIEMENS ISI'
# (0012,0000) Group Length                        UL: 758
# (0012,0062) Patient Identity Removed            CS: 'YES'
# (0012,0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012,0064)  De-identification Method Code Sequence  8 item(s) ----
#    (0008,0000) Group Length                        UL: 76
#    (0008,0100) Code Value                          SH: '113100'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008,0000) Group Length                        UL: 58
#    (0008,0100) Code Value                          SH: '113101'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008,0000) Group Length                        UL: 56
#    (0008,0100) Code Value                          SH: '113103'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Graphics Option'
#    ---------
#    (0008,0000) Group Length                        UL: 58
#    (0008,0100) Code Value                          SH: '113105'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008,0000) Group Length                        UL: 80
#    (0008,0100) Code Value                          SH: '113107'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#    ---------
#    (0008,0000) Group Length                        UL: 72
#    (0008,0100) Code Value                          SH: '113108'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008,0000) Group Length                        UL: 64
#    (0008,0100) Code Value                          SH: '113109'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008,0000) Group Length                        UL: 60
#    (0008,0100) Code Value                          SH: '113111'
#    (0008,0102) Coding Scheme Designator            SH: 'DCM'
#    (0008,0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013,0000) Private Creator                     UN: b'.\x00\x00\x00'
# (0013,0010) Private tag data                    LO: 'CTP'
# (0013,1010) Private tag data                    UN: b'TCGA-LUAD\x00'
# (0013,1013) Private tag data                    UN: b'77779002'
# (0018,0000) Group Length                        UL: 262
# (0018,0010) Contrast/Bolus Agent                LO: 'APPLIED'
# (0018,0015) Body Part Examined                  CS: 'CHEST'
# (0018,0050) Slice Thickness                     DS: '5'
# (0018,0060) KVP                                 DS: '120'
# (0018,1020) Software Versions                   LO: 'VA20Q'
# (0018,1030) Protocol Name                       LO: 'PE-Fast + 40 and over Delay'
# (0018,1100) Reconstruction Diameter             DS: '336'
# (0018,1110) Distance Source to Detector         DS: '1040'
# (0018,1111) Distance Source to Patient          DS: '570'
# (0018,1120) Gantry/Detector Tilt                DS: '0'
# (0018,1130) Table Height                        DS: '139'
# (0018,1140) Rotation Direction                  CS: 'CW'
# (0018,1150) Exposure Time                       IS: '500'
# (0018,1151) X-Ray Tube Current                  IS: '391'
# (0018,1152) Exposure                            IS: '120'
# (0018,1160) Filter Type                         SH: '0'
# (0018,1170) Generator Power                     IS: '46'
# (0018,1190) Focal Spot(s)                       DS: '1.2'
# (0018,1210) Convolution Kernel                  SH: 'B60f'
# (0018,5100) Patient Position                    CS: 'HFS'
# (0019,0000) Private Creator                     UN: b'\x9e\x00\x00\x00'
# (0019,0010) Private tag data                    LO: 'SIEMENS CT VA0  COAD'
# (0019,0011) Private tag data                    LO: 'SIEMENS CM VA0  CMS'
# (0019,0012) Private tag data                    LO: 'SIEMENS DLR.01'
# (0019,0013) Private tag data                    LO: 'SIEMENS SIENET'
# (0019,1090) [Osteo Offset]                      DS: '0'
# (0019,1092) [Osteo Regression Line Slope]       DS: '0.958'
# (0019,1093) [Osteo Regression Line Intercept]   DS: '0.86'
# (0019,1096) [Osteo Phantom Number]              IS: '0'
# (0019,10B0) [Feed per Rotation]                 DS: '16.3'
# (0020,0000) Group Length                        UL: 382
# (0020,000D) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.142043828961014314666225060208
# (0020,000E) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.198754632690942685150635177035
# (0020,0010) Study ID                            SH: ''
# (0020,0011) Series Number                       IS: '5'
# (0020,0012) Acquisition Number                  IS: '4'
# (0020,0013) Instance Number                     IS: '27'
# (0020,0030) Image Position                      DS: [-168, -168, 0]
# (0020,0032) Image Position (Patient)            DS: [-150, -307, -155]
# (0020,0035) Image Orientation                   DS: [1, 0, 0, 0, 1, 0]
# (0020,0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020,0050) Location                            DS: '-155'
# (0020,0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.7777.9002.199390780590194958655951125957
# (0020,0070) Image Geometry Type                 LO: 'PLANAR'
# (0020,1040) Position Reference Indicator        LO: ''
# (0020,1041) Slice Location                      DS: '-155'
# (0021,0000) Private Creator                     UN: b'\x14\x00\x00\x00'
# (0021,0010) Private tag data                    LO: 'SIEMENS MED'
# (0028,0000) Group Length                        UL: 288
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028,0005) Image Dimensions                    US: 2
# (0028,0010) Rows                                US: 512
# (0028,0011) Columns                             US: 512
# (0028,0030) Pixel Spacing                       DS: [006.562500e-01, 006.562500e-01]
# (0028,0040) Image Format                        CS: 'RECT'
# (0028,0060) Compression Code                    CS: 'NONE'
# (0028,0100) Bits Allocated                      US: 16
# (0028,0101) Bits Stored                         US: 12
# (0028,0102) High Bit                            US: 11
# (0028,0103) Pixel Representation                US: 0
# (0028,0200) Image Location                      US: 32736
# (0028,0301) Burned In Annotation                CS: 'NO'
# (0028,0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028,1050) Window Center                       DS: [80, 10]
# (0028,1051) Window Width                        DS: [500, 400]
# (0028,1052) Rescale Intercept                   DS: '-1024.000000'
# (0028,1053) Rescale Slope                       DS: '1.000244'
# (0028,1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0029,0000) Private Creator                     UN: b'T\x00\x00\x00'
# (0029,0010) Private tag data                    LO: 'SIEMENS CSA HEADER'
# (0029,0011) Private tag data                    LO: 'SIEMENS MEDCOM HEADER'
# (0029,0012) Private tag data                    LO: 'SIEMENS MED DISPLAY'
# (0032,0000) Group Length                        UL: 90
# (0032,000A) Study Status ID                     CS: 'SCHEDULED'
# (0032,1000) Scheduled Study Start Date          DA: '19840713'
# (0032,1001) Scheduled Study Start Time          TM: '170000.000000'
# (0032,1060) Requested Procedure Description     LO: 'CT Hd/Brain w/oBH'
# (0032,4000) Study Comments                      LT: ''
# (0038,0000) Group Length                        UL: 10
# (0038,0050) Special Needs                       LO: 'BH'
# (0091,0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
# (0091,0010) Private tag data                    LO: 'SIENET'
# (0095,0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
# (0095,0010) Private tag data                    LO: 'SIENET'
# (0097,0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
# (0097,0010) Private tag data                    LO: 'SIENET'
# (0099,0000) Private Creator                     UN: b'\x0e\x00\x00\x00'
# (0099,0010) Private tag data                    LO: 'SIENET'
# (7FE0,0000) Group Length                        UL: 524296
# (7FE0,0010) Pixel Data                          OW: Array of 524288 elements

# %%
# Print specific metadata fields from the DICOM file
print("pydicom_file[0x0008,0x0032]:",pydicom_file[0x0008,0x0032])
print("pydicom_file.AcquisitionTime :",pydicom_file.AcquisitionTime )
# Out:
# pydicom_file[0x0008,0x0032]: (0008,0032) Acquisition Time                    TM: '083734.355000'
# pydicom_file.AcquisitionTime : 083734.355000

# %%
# Extract the pixel data from the DICOM file and store it as a CT image
ct = pydicom_file.pixel_array
plt.figure()
plt.imshow(ct,cmap='gray')

# %%
# Define the path to the directory containing DICOM files
path_ct = Path('/dicom_dir')

# %%
# Get a list of all files in the DICOM directory
all_files = list(path_ct.glob("*"))

# %%
# Initialize an empty list to store DICOM data
ct_data=[]
# Loop through all files in the directory and read each DICOM file
for path in all_files:
  data = pydicom.dcmread(path)
  ct_data.append(data)

# %%
# Sort the DICOM data by SliceLocation to ensure correct order
ct_data_sorted = sorted(ct_data , key= lambda slice: slice.SliceLocation)
# Print the SliceLocation of the first 10 slices
for slice in ct_data_sorted[:10]:
  print(slice.SliceLocation)
# Out:
# -1168.4
# -948.5
# -948.2
# -918.5
# -901
# -874
# -874
# -816.5
# -795.030
# -763.5

# %%
# Initialize an empty list to store pixel arrays of all slices
all_slice =[]
# Extract pixel arrays from sorted DICOM data
for slice in ct_data_sorted:
  all_slice.append(slice.pixel_array)
len(all_slice)
# Out:
# 100

# %%
# Create a 3x4 grid of subplots for displaying slices
fig , axis = plt.subplots(3,4,figsize = (15,15))
# Initialize a counter for selecting slices to display
slice_counter = 0
# Loop through the 3x4 grid and display the first 12 slices
for i in range (3):
  for j in range (4):
    axis[i][j].imshow(all_slice[slice_counter],cmap = 'gray')
    slice_counter +=1
